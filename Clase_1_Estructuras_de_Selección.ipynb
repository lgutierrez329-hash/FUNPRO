# %% [markdown]
# <a href="https://colab.research.google.com/github/lgutierrez329-hash/FUNPRO/blob/main/Clase_1_Estructuras_de_Selecci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Saludando al mundo

# %%
Comando de entrada

# %% [markdown]
# ##Comandos de entrada
# * print(): Imprime en la consola
# * input(): ingresa/asigna/imprime
#
# ```
# # variable=input("lo que está aquí, se imprime")
# ```

# %%
nombre=input("Cuál es tu nombre? ")
# Out:
# Cuál es tu nombre? LUIS FERNANDO

# %%
nombre
# Out:
# 'LUIS FERNANDO'

# %%
print("Hola mundo😎💖😁")
# Out:
# Hola mundo😎💖😁

# %%
#CONCATENACIÓN: Unir dos tipos de datos
print("Hola",nombre)
# Out:
# Hola LUIS FERNANDO

# %%
print(f"Hola {nombre}")
# Out:
# Hola LUIS FERNANDO

# %%
respuesta

# %%
respuesta=input("Detecto que no hay gasolina en el tanque. Desea ir a una gasolinera?")
# Out:
# Detecto que no hay gasolina en el tanque. Desea ir a una gasolinera? si

# %%
respuesta
# Out:
# ' si'
